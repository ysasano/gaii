# %%
import numpy as np
import matplotlib.pyplot as plt
import var

A = np.array([[0.9, 0.03], [0.03, 0.9]])
Sigma = np.array( [[0.1, 0], [0, 0.1]])
initiali_state= np.random.multivariate_normal([0, 0], [[0.1, 0], [0, 0.1]], size=1)[0]

stateList = var.generate(initiali_state, A, Sigma)
plt.plot(stateList)
